# %% [markdown]
# Import the Pandas and Numpy libraries and load in the data file
# ---

# %%
import pandas as pd
import numpy as np

demo = pd.read_csv('Demographics.csv')
bmx = pd.read_csv('BodyMeasures.csv')
ocq = pd.read_csv('Occupation.csv')

# %% [markdown]
# Duplicate Rows
# ---

# %%
demo.sort_values('SEQN', inplace=True)
ind = demo['SEQN'].duplicated(keep=False)

print('Duplicate rows: %i' % len(demo.loc[ind,:]))
demo.loc[ind,:].head()
# Out:
# Duplicate rows: 1213
#        SEQN  SDDSRVYR RIDSTATR  RIDEXMON RIAGENDR  RIDAGEYR  RIDAGEMN  \
# 10491    15       1.0     exam       1.0   Female      38.0     459.0
# 14       15       1.0     exam       1.0   Female      38.0     459.0
# 10102    42       1.0     Both       2.0   Female      18.0     223.0
# 9991     42       1.0     Both       2.0   Female      18.0     223.0
# 41       42       1.0     Both       2.0   Female      18.0     223.0
#
#        RIDAGEEX            RIDRETH1  RIDRETH2  ...       WTIREP43  \
# 10491     460.0  Non-Hispanic White       1.0  ...  110651.142444
# 14        460.0  Non-Hispanic White       1.0  ...  110651.142444
# 10102     224.0  Non-Hispanic Black       2.0  ...    9118.858665
# 9991      224.0  Non-Hispanic Black       2.0  ...    9118.858665
# 41        224.0  Non-Hispanic Black       2.0  ...    9118.858665
#
#             WTIREP44       WTIREP45       WTIREP46       WTIREP47  \
# 10491  109666.993353  113803.429690   33314.865599  113109.089839
# 14     109666.993353  113803.429690  112123.984382  113109.089839
# 10102    9139.612368    8948.540469    9083.673929       0.000000
# 9991     9139.612368    8948.540469    9083.673929       0.000000
# 41       9139.612368    8948.540469    9083.673929       0.000000
#
#             WTIREP48       WTIREP49       WTIREP50       WTIREP51  \
# 10491  108722.224537  109264.251804  110186.143135  112750.496899
# 14     108722.224537  109264.251804  110186.143135  112750.496899
# 10102    9095.898010    9290.163552    9459.795274    9312.800370
# 9991     9095.898010    9290.163552    9459.795274    9312.800370
# 41       9095.898010    9290.163552    9459.795274    9312.800370
#
#             WTIREP52
# 10491  110008.647960
# 14     110008.647960
# 10102    9518.027784
# 9991     9518.027784
# 41       9518.027784
#
# [5 rows x 144 columns]

# %%
demo.drop_duplicates(inplace=True)

ind = demo['SEQN'].duplicated(keep=False)

print('Duplicate rows: ' + str(len(demo.loc[ind,:])))
demo.loc[ind,:].head()
# Out:
# Duplicate rows: 814
#        SEQN  SDDSRVYR RIDSTATR  RIDEXMON RIAGENDR  RIDAGEYR  RIDAGEMN  \
# 10491    15       1.0     exam       1.0   Female      38.0     459.0
# 14       15       1.0     exam       1.0   Female      38.0     459.0
# 56       57       1.0      NaN       NaN    Male        NaN       NaN
# 10307    57       NaN    Both        2.0      NaN      39.0     475.0
# 59       60       1.0     Exam       2.0     Male       5.0      70.0
#
#        RIDAGEEX            RIDRETH1  RIDRETH2  ...       WTIREP43  \
# 10491     460.0  Non-Hispanic White       1.0  ...  110651.142444
# 14        460.0  Non-Hispanic White       1.0  ...  110651.142444
# 56          NaN                 NaN       NaN  ...            NaN
# 10307     476.0  Non-Hispanic White       1.0  ...   93148.702889
# 59         71.0  Non-Hispanic White       1.0  ...   41858.569852
#
#             WTIREP44       WTIREP45       WTIREP46       WTIREP47  \
# 10491  109666.993353  113803.429690   33314.865599  113109.089839
# 14     109666.993353  113803.429690  112123.984382  113109.089839
# 56      92103.709621   95372.027071   94115.137170   95281.362267
# 10307            NaN            NaN            NaN            NaN
# 59      41576.241533   43040.796615   43167.384386   42922.779884
#
#             WTIREP48       WTIREP49       WTIREP50       WTIREP51  \
# 10491  108722.224537  109264.251804  110186.143135  112750.496899
# 14     108722.224537  109264.251804  110186.143135  112750.496899
# 56      91309.320440   91624.769642            NaN            NaN
# 10307            NaN            NaN   92801.907240   94266.582871
# 59      41775.622676       0.000000   42091.705803   42039.843678
#
#             WTIREP52
# 10491  110008.647960
# 14     110008.647960
# 56               NaN
# 10307   91977.373860
# 59      41556.080118
#
# [5 rows x 144 columns]

# %%
import itertools

dup_id = demo.loc[ind,'SEQN'].unique()

for id in dup_id:
    dup_rows = np.where(demo['SEQN'] == id)[0]
    for (row1, row2) in itertools.product(dup_rows, repeat=2):
        demo.iloc[row1,:] = demo.iloc[row1,:].fillna(demo.iloc[row2,:], axis=0)

# %%
demo.drop_duplicates(inplace=True)

ind = demo['SEQN'].duplicated(keep=False)

print('Duplicate rows: %i' % len(demo.loc[ind,:]))
demo.loc[ind,:].head()
# Out:
# Duplicate rows: 416
#        SEQN  SDDSRVYR RIDSTATR  RIDEXMON RIAGENDR  RIDAGEYR  RIDAGEMN  \
# 10491    15       1.0     exam       1.0   Female      38.0     459.0
# 14       15       1.0     exam       1.0   Female      38.0     459.0
# 59       60       1.0     Exam       2.0     Male       5.0      70.0
# 10392    60       1.0     Exam       1.0     Male       5.0      70.0
# 10485    83       1.0     exam       2.0   Female      60.0     731.0
#
#        RIDAGEEX            RIDRETH1  RIDRETH2  ...       WTIREP43  \
# 10491     460.0  Non-Hispanic White       1.0  ...  110651.142444
# 14        460.0  Non-Hispanic White       1.0  ...  110651.142444
# 59         71.0  Non-Hispanic White       1.0  ...   41858.569852
# 10392      71.0  Non-Hispanic White       1.0  ...   41858.569852
# 10485     731.0  Non-Hispanic Black       4.0  ...   10840.799501
#
#             WTIREP44       WTIREP45       WTIREP46       WTIREP47  \
# 10491  109666.993353  113803.429690   33314.865599  113109.089839
# 14     109666.993353  113803.429690  112123.984382  113109.089839
# 59      41576.241533   43040.796615   43167.384386   42922.779884
# 10392   41576.241533   43040.796615   12698.465159   20321.432353
# 10485   10774.881528   10553.677856   10816.699831   10998.350416
#
#             WTIREP48       WTIREP49       WTIREP50       WTIREP51  \
# 10491  108722.224537  109264.251804  110186.143135  112750.496899
# 14     108722.224537  109264.251804  110186.143135  112750.496899
# 59      41775.622676       0.000000   42091.705803   42039.843678
# 10392   41775.622676       0.000000   42091.705803   42039.843678
# 10485   10902.784484   10863.252191   10954.274380   10864.016537
#
#             WTIREP52
# 10491  110008.647960
# 14     110008.647960
# 59      41556.080118
# 10392   41556.080118
# 10485       0.000000
#
# [5 rows x 144 columns]

# %%
ind = demo['SEQN'].duplicated(keep=False)

demo = demo.loc[~ind,:]

ind = demo['SEQN'].duplicated(keep=False)
print('Duplicate rows: %i' % len(demo.loc[ind,:]))
demo.loc[ind,:].head()
# Out:
# Duplicate rows: 0
# Empty DataFrame
# Columns: [SEQN, SDDSRVYR, RIDSTATR, RIDEXMON, RIAGENDR, RIDAGEYR, RIDAGEMN, RIDAGEEX, RIDRETH1, RIDRETH2, DMQMILIT, DMDBORN, DMDCITZN, DMDYRSUS, DMDEDUC3, DMDEDUC2, DMDEDUC, DMDSCHOL, DMDMARTL, DMDHHSIZ, INDHHINC, INDFMINC, INDFMPIR, RIDEXPRG, RIDPREG, DMDHRGND, DMDHRAGE, DMDHRBRN, DMDHREDU, DMDHRMAR, DMDHSEDU, WTINT2YR, WTINT4YR, WTMEC2YR, WTMEC4YR, SDMVPSU, SDMVSTRA, SDJ1REPN, DMAETHN, DMARACE, WTMREP01, WTMREP02, WTMREP03, WTMREP04, WTMREP05, WTMREP06, WTMREP07, WTMREP08, WTMREP09, WTMREP10, WTMREP11, WTMREP12, WTMREP13, WTMREP14, WTMREP15, WTMREP16, WTMREP17, WTMREP18, WTMREP19, WTMREP20, WTMREP21, WTMREP22, WTMREP23, WTMREP24, WTMREP25, WTMREP26, WTMREP27, WTMREP28, WTMREP29, WTMREP30, WTMREP31, WTMREP32, WTMREP33, WTMREP34, WTMREP35, WTMREP36, WTMREP37, WTMREP38, WTMREP39, WTMREP40, WTMREP41, WTMREP42, WTMREP43, WTMREP44, WTMREP45, WTMREP46, WTMREP47, WTMREP48, WTMREP49, WTMREP50, WTMREP51, WTMREP52, WTIREP01, WTIREP02, WTIREP03, WTIREP04, WTIREP05, WTIREP06, WTIREP07, WTIREP08, ...]
# Index: []
#
# [0 rows x 144 columns]

# %% [markdown]
# Duplicate Columns
# ---

# %%
set(demo.columns).intersection(bmx.columns)
# Out:
# {'RIDAGEYR', 'SEQN'}

# %%
bmx.drop('RIDAGEYR', 1, inplace=True)

set(demo.columns).intersection(bmx.columns)
# Out:
# {'SEQN'}

# %%
demo.loc[:,['SEQN']].dtypes
bmx.loc[:,['SEQN']].dtypes
# Out:
# SEQN    int64
# dtype: object

# %%
bmx['SEQN'] = bmx['SEQN'].astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-72e20cc1516d> in <module>
# ----> 1 bmx['SEQN'] = bmx['SEQN'].astype(np.float64)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     993     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     994         # Explicit copy, or required since NumPy can't view from / to object.
# --> 995         return arr.astype(dtype, copy=True)
#     996
#     997     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'Jane Doe'

# %%
dataset = pd.merge(demo, bmx, on='SEQN', how='inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b1a449039581> in <module>
# ----> 1 dataset = pd.merge(demo, bmx, on='SEQN', how='inner')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     654         # validate the merge keys dtypes. We may need to coerce
#     655         # to avoid incompatible dtypes
# --> 656         self._maybe_coerce_merge_keys()
#     657
#     658         # If argument passed to validate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1163                     inferred_right in string_types and inferred_left not in string_types
#    1164                 ):
# -> 1165                     raise ValueError(msg)
#    1166
#    1167             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat

# %% [markdown]
# Individual Practice
# ---
#
# 1. Find the column with the highest percentage of missing information in demographics
# 2. Remove confidential pregnancy status for minors (rows 'RIDEXPRG' and 'RIDPREG')
# 3. Fix or remove duplicate rows in the occupation file (ocq DataFrame)
# 4. Check for duplicate columns between ocq and demo
# 5. Merge all 3 files into a single dataset

# %%
ocq.sort_values('SEQN', inplace=True)
ind = ocq['SEQN'].duplicated(keep=False)

print('Duplicate rows: %i' % len(ocq.loc[ind,:]))
ocq.loc[ind,:].head()
# Out:
# Duplicate rows: 884
#       SEQN  OCQ130  OCQ150  OCQ160  OCQ180  OCQ210  OCD230  OCD240  OCQ260  \
# 18    26.0     7.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7437  26.0     7.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7322  27.0     NaN     1.0     NaN     6.0     2.0    36.0     6.0     5.0
# 19    27.0     NaN     1.0     NaN     6.0     2.0    36.0     6.0     5.0
# 7655  44.0     7.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#       OCD270  ...  OCD390  OCD395  OCQ420  OCQ430  OCQ440  OCQ450  OCQ470G  \
# 18       NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 7437     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 7322    48.0  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 19      48.0  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 7655     NaN  ...     NaN     NaN     9.0     NaN     NaN     NaN      NaN
#
#       OCD470  OCD480  RIAGENDR
# 18       NaN     NaN    Female
# 7437     NaN     NaN    Female
# 7322     NaN     NaN      Male
# 19       NaN     NaN      Male
# 7655     NaN     NaN         F
#
# [5 rows x 37 columns]

# %%
ocq.drop_duplicates(inplace=True)

ind = ocq['SEQN'].duplicated(keep=False)

print('Duplicate rows: ' + str(len(ocq.loc[ind,:])))
ocq.loc[ind,:].head()
# Out:
# Duplicate rows: 584
#        SEQN  OCQ130  OCQ150  OCQ160  OCQ180  OCQ210  OCD230  OCD240  OCQ260  \
# 7655   44.0     7.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 27     44.0     7.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 28     45.0     NaN     NaN     NaN    45.0     NaN    19.0     NaN     NaN
# 7504   45.0     NaN     1.0     NaN     NaN     NaN     NaN    14.0     1.0
# 7457  167.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#       OCD270  ...  OCD390  OCD395  OCQ420  OCQ430  OCQ440  OCQ450  OCQ470G  \
# 7655     NaN  ...     NaN     NaN     9.0     NaN     NaN     NaN      NaN
# 27       NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 28      36.0  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 7504     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 7457     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
#
#       OCD470  OCD480  RIAGENDR
# 7655     NaN     NaN         F
# 27       NaN     NaN         F
# 28       NaN     NaN       NaN
# 7504     NaN     NaN         F
# 7457     NaN     NaN    Female
#
# [5 rows x 37 columns]

# %%
import itertools

dup_id = ocq.loc[ind,'SEQN'].unique()

for id in dup_id:
    dup_rows = np.where(ocq['SEQN'] == id)[0]
    for (row1, row2) in itertools.product(dup_rows, repeat=2):
        ocq.iloc[row1,:] = ocq.iloc[row1,:].fillna(ocq.iloc[row2,:], axis=0)

# %%
ocq.drop_duplicates(inplace=True)

ind = ocq['SEQN'].duplicated(keep=False)

print('Duplicate rows: ' + str(len(ocq.loc[ind,:])))
ocq.loc[ind,:].head()
# Out:
# Duplicate rows: 158
#        SEQN  OCQ130  OCQ150  OCQ160  OCQ180  OCQ210  OCD230  OCD240  OCQ260  \
# 7737  197.0     NaN     4.0     NaN     NaN     NaN     NaN     NaN     1.0
# 145   197.0     NaN     4.0     NaN     NaN     NaN     NaN     NaN     1.0
# 7649  249.0     NaN     1.0     NaN    10.0     2.0     4.0    29.0     1.0
# 177   249.0     NaN     1.0     NaN    10.0     2.0     4.0    37.0     1.0
# 385   551.0     NaN     4.0     1.0    37.0     NaN     NaN     NaN     NaN
#
#       OCD270  ...  OCD390  OCD395  OCQ420  OCQ430  OCQ440  OCQ450  OCQ470G  \
# 7737     NaN  ...    38.0   120.0     2.0     7.0    20.0     NaN      NaN
# 145      NaN  ...    38.0   120.0     2.0     7.0    20.0     NaN      NaN
# 7649     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 177      4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 385      NaN  ...    20.0    48.0     2.0     NaN     NaN     NaN      NaN
#
#       OCD470  OCD480  RIAGENDR
# 7737     NaN    24.0      Male
# 145      NaN    24.0      Male
# 7649     NaN     NaN      Male
# 177      NaN     NaN      Male
# 385      NaN     NaN    Female
#
# [5 rows x 37 columns]

# %%
ind = ocq['SEQN'].duplicated(keep=False)

ocq = ocq.loc[~ind,:]

ind = ocq['SEQN'].duplicated(keep=False)
print('Duplicate rows: %i' % len(ocq.loc[ind,:]))
ocq.loc[ind,:].head()
# Out:
# Duplicate rows: 0
# Empty DataFrame
# Columns: [SEQN, OCQ130, OCQ150, OCQ160, OCQ180, OCQ210, OCD230, OCD240, OCQ260, OCD270, OCQ280, OCQ290G, OCQ290Q, OCQ300, OCQ310A, OCQ310B, OCQ310C, OCQ330A, OCQ330B, OCQ330C, OCQ330D, OCQ330E, OCQ340, OCQ350, OCQ360, OCQ380, OCQ390G, OCD390, OCD395, OCQ420, OCQ430, OCQ440, OCQ450, OCQ470G, OCD470, OCD480, RIAGENDR]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# 4. Check for duplicate columns between ocq and demo

# %%
set(ocq.columns).intersection(demo.columns)
# Out:
# {'RIAGENDR', 'SEQN'}

# %%
ocq.drop('RIAGENDR', 1, inplace=True)

set(demo.columns).intersection(ocq.columns)
# Out:
# {'SEQN'}

# %%
dataset = pd.merge(dataset, ocq, on='SEQN', how='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-ef8e49341168> in <module>
# ----> 1 dataset = pd.merge(dataset, ocq, on='SEQN', how='inner')
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# Save Data Files
# ---

# %%
# demo.to_csv('Demographics.csv', index=False)
# bmx.to_csv('BodyMeasures.csv', index=False)
# ocq.to_csv('Occupation.csv', index=False)
# dataset.to_csv('MyDataset.csv', index=False)
